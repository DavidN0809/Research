# %%
import sounddevice as sd

print(sd.query_devices())
# Out:
#    0 HDA Intel PCH: ALC897 Analog (hw:0,0), ALSA (2 in, 2 out)
#    1 HDA Intel PCH: HDMI 0 (hw:0,3), ALSA (0 in, 8 out)
#    2 HDA Intel PCH: HDMI 1 (hw:0,7), ALSA (0 in, 8 out)
#    3 HDA Intel PCH: HDMI 2 (hw:0,8), ALSA (0 in, 8 out)
#    4 HDA Intel PCH: HDMI 3 (hw:0,9), ALSA (0 in, 8 out)
#    5 HDA NVidia: HDMI 0 (hw:1,3), ALSA (0 in, 8 out)
#    6 HDA NVidia: HDMI 1 (hw:1,7), ALSA (0 in, 8 out)
#    7 HDA NVidia: HDMI 2 (hw:1,8), ALSA (0 in, 8 out)
#    8 HDA NVidia: HDMI 3 (hw:1,9), ALSA (0 in, 8 out)
#    9 sysdefault, ALSA (128 in, 128 out)
#   10 front, ALSA (0 in, 2 out)
#   11 surround40, ALSA (0 in, 2 out)
#   12 surround51, ALSA (0 in, 2 out)
#   13 surround71, ALSA (0 in, 2 out)
#   14 hdmi, ALSA (0 in, 8 out)
#   15 samplerate, ALSA (128 in, 128 out)
#   16 speexrate, ALSA (128 in, 128 out)
#   17 jack, ALSA (2 in, 2 out)
#   18 pipewire, ALSA (64 in, 64 out)
#   19 pulse, ALSA (32 in, 32 out)
#   20 upmix, ALSA (8 in, 8 out)
#   21 vdownmix, ALSA (6 in, 6 out)
#   22 dmix, ALSA (0 in, 2 out)
# * 23 default, ALSA (32 in, 32 out)
#   24 Built-in Audio Analog Stereo, JACK Audio Connection Kit (4 in, 2 out)
#   25 ALSA plug-in [python3.10]-77, JACK Audio Connection Kit (0 in, 0 out)
#   26 ALSA plug-in [python3.10]-108, JACK Audio Connection Kit (0 in, 0 out)
#   27 ALSA plug-in [python3.10], JACK Audio Connection Kit (0 in, 0 out)
#   28 ALSA plug-in [python3.10]-205, JACK Audio Connection Kit (0 in, 0 out)
#   29 ALSA plug-in [python3.10]-134, JACK Audio Connection Kit (0 in, 0 out)
#   30 ALSA plug-in [python3.10]-151, JACK Audio Connection Kit (0 in, 0 out)
#   31 ALSA plug-in [python3.10]-154, JACK Audio Connection Kit (0 in, 0 out)
#   32 ALSA plug-in [python3.10]-239, JACK Audio Connection Kit (0 in, 0 out)

# %%
import sounddevice as sd
import scipy.io.wavfile as wav
import matplotlib.pyplot as plt
import numpy as np

fs_target = 16000
recorded_audio = []

# Define the callback function for recording and playing back audio
def callback(indata, outdata, frames, time, status):
    if status:
        print(status, file=sys.stderr)
    outdata[:] = indata
    recorded_audio.append(indata)

# Choose device numbers for input and output devices
input_device = 23  # Blue Snowball microphone
output_device = 23  # Headphones

# Open a stream for recording and playback
with sd.Stream(device=(input_device, output_device), blocksize=8192, samplerate=fs_target, channels=1, callback=callback):
    print('Testing input/output devices...')
    sd.sleep(5000)
    print('Testing complete')
    
recorded_audio = np.hstack(recorded_audio)

# Save the recorded audio to a WAV file
wav.write('test.wav', fs_target, recorded_audio)
fs, audio = wav.read('test.wav')
plt.plot(audio)
plt.show()
# Out:
# Testing input/output devices...
# Testing complete

# %%
import numpy as np
import sounddevice as sd
#import tflite_runtime.interpreter as tflite
import tensorflow as tf

from scipy.io.wavfile import write
import scipy.io.wavfile as wav

recorded_audio = []

# set some parameters
block_len_ms = 32 
block_shift_ms = 8
input_fs = 44100
fs_target = 16000

# create the interpreters
interpreter_1 = tf.lite.Interpreter(model_path='./pretrained_model/model_1.tflite')
interpreter_1.allocate_tensors()
interpreter_2 = tf.lite.Interpreter(model_path='./pretrained_model/model_2.tflite')
interpreter_2.allocate_tensors()

# Get input and output tensors.
input_details_1 = interpreter_1.get_input_details()
output_details_1 = interpreter_1.get_output_details()
input_details_2 = interpreter_2.get_input_details()
output_details_2 = interpreter_2.get_output_details()

# create states for the lstms
states_1 = np.zeros(input_details_1[1]['shape']).astype('float32')
states_2 = np.zeros(input_details_2[1]['shape']).astype('float32')

# calculate shift and length
block_shift = int(np.round(fs_target * (block_shift_ms / 1000)))
block_len = int(np.round(fs_target * (block_len_ms / 1000)))

# create buffer
in_buffer = np.zeros((block_len)).astype('float32')
out_buffer = np.zeros((block_len)).astype('float32')

from scipy.signal import resample

def callback(indata, outdata, frames, time, status):
    # buffer and states to global
    global in_buffer, out_buffer, states_1, states_2
    if status:
        print(status)
        
    # resample input data to 16kHz
    indata_resampled = resample(indata, int(len(indata) * fs_target / input_fs))
    
    # write to buffer
    in_buffer[:-block_shift] = in_buffer[block_shift:]
    in_buffer[-block_shift:] = np.squeeze(indata_resampled)
    
    # calculate fft of input block
    in_block_fft = np.fft.rfft(in_buffer)
    in_mag = np.abs(in_block_fft)
    in_phase = np.angle(in_block_fft)
    
    # reshape magnitude to input dimensions
    in_mag = np.reshape(in_mag, (1,1,-1)).astype('float32')
    
    # set tensors to the first model
    interpreter_1.set_tensor(input_details_1[1]['index'], states_1)
    interpreter_1.set_tensor(input_details_1[0]['index'], in_mag)
   
    # run calculation 
    interpreter_1.invoke()
    
    # get the output of the first block
    out_mask = interpreter_1.get_tensor(output_details_1[0]['index']) 
    states_1 = interpreter_1.get_tensor(output_details_1[1]['index'])   
    
    # calculate the ifft
    estimated_complex = in_mag * out_mask * np.exp(1j * in_phase)
    estimated_block = np.fft.irfft(estimated_complex)
    
    # reshape the time domain block
    estimated_block = np.reshape(estimated_block, (1,1,-1)).astype('float32')
    
    # set tensors to the second block
    interpreter_2.set_tensor(input_details_2[1]['index'], states_2)
    interpreter_2.set_tensor(input_details_2[0]['index'], estimated_block)
    
    # run calculation
    interpreter_2.invoke()
    
    # get output tensors
    out_block = interpreter_2.get_tensor(output_details_2[0]['index']) 
    states_2 = interpreter_2.get_tensor(output_details_2[1]['index']) 
    
    # write to buffer
    out_buffer[:-block_shift] = out_buffer[block_shift:]
    out_buffer[-block_shift:] = np.zeros((block_shift))
    out_buffer  += np.squeeze(out_block)
    
    # output to soundcard
    outdata[:] = np.expand_dims(out_buffer[:block_shift], axis=-1)
    recorded_audio.append(outdata)


#choose the default input and output devices
input_device = 23
output_device = 23

try:
    with sd.Stream(device=(input_device, output_device),
                   samplerate=input_fs, blocksize=block_shift,
                   dtype=np.float32, latency=0.2,
                   channels=1, callback=callback):
        print('#' * 80)
        print('press Return to quit')
        print('#' * 80)
        input()

except KeyboardInterrupt:
    parser.exit('')
# Out:
# ################################################################################
# press Return to quit
# ################################################################################
# Exception ignored from cffi callback <function _StreamBase.__init__.<locals>.callback_ptr at 0x7fcc77c17010>:
# Traceback (most recent call last):
#   File "/home/david/.local/lib/python3.10/site-packages/sounddevice.py", line 886, in callback_ptr
#     return _wrap_callback(
#   File "/home/david/.local/lib/python3.10/site-packages/sounddevice.py", line 2687, in _wrap_callback
#     callback(*args)
#   File "/tmp/ipykernel_15401/1896490978.py", line 54, in callback
# ValueError: could not broadcast input array from shape (46,) into shape (128,)
